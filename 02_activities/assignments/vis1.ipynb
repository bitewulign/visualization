# %%
import pandas as pd

# Load dataset (adjust the filename based on what you downloaded)
df = pd.read_csv("Road Reconstruction Program - 4326.csv")

# Check basic info
print(df.info())

# Preview first few rows
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   _id                              391 non-null    int64
#  1   OBJECTID                         391 non-null    int64
#  2   PROJ_NUM                         388 non-null    object
#  3   LAST_UPDATED_DATE                391 non-null    object
#  4   PROJECT                          391 non-null    object
#  5   LOCATION                         391 non-null    object
#  6   DETAILS                          391 non-null    object
#  7   DURATION/ Construction Timeline  391 non-null    object
#  8   STATUS                           391 non-null    object
#  9   INV_PRIORITY                     246 non-null    object
#  10  OWNER                            391 non-null    object
#  11  CONTACT_NAME                     391 non-null    object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Year' column to numeric (adjust column name accordingly)
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Group by year
yearly_projects = df.groupby('Year').size()

# Plot
plt.figure(figsize=(10,5))
sns.barplot(x=yearly_projects.index, y=yearly_projects.values, palette="Blues_r")

# Titles and labels
plt.title("Number of Road Reconstruction Projects by Year")
plt.xlabel("Year")
plt.ylabel("Number of Projects")

plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bitka\anaconda3\envs\dsi_participant\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       2 import seaborn as sns
# ...
